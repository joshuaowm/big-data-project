# %% [markdown]
# # Big Data Project Script
#
# Choose, implement and evaluate a ML algorithm for land cover image classification on FRACTAL.
#
#
# Datasets (FRACTAL): https://huggingface.co/datasets/IGNF/FRACTAL

# %%
# Pseudocode
#
